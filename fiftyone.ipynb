# %%
import fiftyone as fo

# The directory containing the dataset to import
dataset_dir = "/media/datasets"

# The type of the dataset being imported
dataset_type = fo.types.YOLOv5Dataset  # for example

# Import the dataset
dataset = fo.Dataset.from_dir(
    dataset_dir=dataset_dir,
    dataset_type=dataset_type,
)
# Out:
#    0% ||--------------|    1/2059 [19.0ms elapsed, 39.1s remaining, 52.7 samples/s]
#  100% |███████████████| 2059/2059 [2.5s elapsed, 0s remaining, 881.8 samples/s]

# %%
# Creates a session and opens the App in the output of the cell
session = fo.launch_app(dataset)
# Out:
#         <iframe
#             width="100%"
#             height="800"
#             src="http://localhost:5151/?notebook=True&subscription=34410442-0b4c-43b1-83ab-0be4fd993cce"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
#
#
# Could not connect session, trying again in 10 seconds
